# %% [markdown]
# <a href="https://colab.research.google.com/github/MaazUliman/web-scraping-pandas/blob/main/project_1_web_scraping_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_premier21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2526/E0.csv")

# %%
df_premier21.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# ...

# %%
df_premier21.rename(columns = {"FTAG":"away_goals","FTHG":"home_goals"},inplace = True)

# %%
df_premier21.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  home_goals  away_goals  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth           4           2
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle           0           0
# 2  E0  16/08/2025  15:00     Brighton       Fulham           1           1
# 3  E0  16/08/2025  15:00   Sunderland     West Ham           3           0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley           3           0
#
#   FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0   H     1     0  ...     2.03     1.78   2.07   1.85     2.03     1.88
# 1   D     0     0  ...     2.05     1.80   2.02   1.89     2.06     1.80
# 2   D     0     0  ...     1.83     2.03   1.93   2.00     1.84     2.03
# 3   H     0     0  ...     1.95     1.90   1.97   1.95     1.95     1.94
# 4   H     1     0  ...     1.98     1.88   1.99   1.93     1.98     1.91
#
#    AvgCAHH  AvgCAHA  BFECAHH  BFECAHA
# ...

# %%
root = "https://www.football-data.co.uk/mmz4281/"

# %%
Root = "https://www.football-data.co.uk/mmz4281/2526/E0.csv"

# %%
leagues = ["E0","E1","E2","E3","EC"]
frames = []
for league in leagues:
  df = pd.read_csv(root + "2122" + "/" + league + ".csv",encoding = "unicode_escape")
  frames.append(df)

# %%
frames[0].head()
# Out:
#   ï»¿Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1     E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2     E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3     E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4     E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# ...

# %%
frames[1].head()
# Out:
#   Div        Date   Time      HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E1  06/08/2021  19:45   Bournemouth     West Brom     2     2   D     1
# 1  E1  07/08/2021  15:00     Blackburn       Swansea     2     1   H     1
# 2  E1  07/08/2021  15:00  Bristol City     Blackpool     1     1   D     1
# 3  E1  07/08/2021  15:00       Cardiff      Barnsley     1     1   D     0
# 4  E1  07/08/2021  15:00         Derby  Huddersfield     1     1   D     1
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.84 -0.25      2.13      1.78   2.13   1.80     2.16
# 1     0  ...     1.70 -0.25      1.77      2.14   1.83   2.09     1.87
# 2     0  ...     1.66 -0.25      1.90      2.00   1.92   1.99     1.92
# 3     0  ...     1.62 -0.25      2.05      1.75   2.14   1.80     2.19
# 4     1  ...     1.60 -0.25      1.88      2.02   1.88   2.01     1.90
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.83     2.09     1.77
# ...

# %%
len(frames)
# Out:
# 5

# %%
leagues = ["E1","E2","E3"]
frames = []
for league in leagues:
  for season in range(20,26):
    df = pd.read_csv(root + str(season)+str(season+1) + "/" + league + ".csv",encoding = "unicode_escape")
    df.insert(1,"Season",season)
    frames.append(df)

# %%
len(frames)
# Out:
# 18

# %%
frames[0].head()
# Out:
#   Div  Season        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0  E1      20  11/09/2020  19:45      Watford  Middlesbrough     1     0   H
# 1  E1      20  12/09/2020  12:30   Birmingham      Brentford     1     0   H
# 2  E1      20  12/09/2020  12:30      Wycombe      Rotherham     0     1   A
# 3  E1      20  12/09/2020  15:00     Barnsley          Luton     0     1   A
# 4  E1      20  12/09/2020  15:00  Bournemouth      Blackburn     3     2   H
#
#    HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...      1.65 -0.50     2.05      1.85   2.04   1.85     2.09
# 1     1  ...      1.67  0.50     1.97      1.93   1.96   1.93     1.97
# 2     0  ...      1.86  0.25     1.99      1.91   1.95   1.93     2.04
# 3     0  ...      1.83 -0.50     1.77      2.02   1.81   2.10     1.87
# 4     1  ...      1.89 -0.50     2.06      1.84   2.07   1.85     2.11
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.88     2.02     1.82
# ...

# %%
frames[17].head()
# Out:
#   ï»¿Div  Season        Date   Time      HomeTeam        AwayTeam  FTHG  FTAG  \
# 0     E3      25  02/08/2025  15:00    Accrington      Gillingham     1     1
# 1     E3      25  02/08/2025  15:00        Barnet  Fleetwood Town     0     2
# 2     E3      25  02/08/2025  15:00   Bristol Rvs       Harrogate     0     1
# 3     E3      25  02/08/2025  15:00     Cambridge      Cheltenham     1     0
# 4     E3      25  02/08/2025  15:00  Chesterfield          Barrow     1     0
#
#   FTR  HTHG  ...  B365CAHA PCAHH PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0   D     0  ...      1.88  1.76  2.12     1.98     1.88     1.92     1.83
# 1   A     0  ...      1.85  2.29  1.65     2.08     1.85     2.00     1.74
# 2   A     0  ...      2.03  1.85  2.00     1.85     2.03     1.78     1.96
# 3   H     0  ...      1.88  1.88  1.97     1.98     1.88     1.90     1.83
# 4   H     1  ...      2.03  1.79  2.06     1.80     2.07     1.73     2.02
#
#    BFECAHH  BFECAHA  Unnamed: 132
# ...

# %%
frames[0].head()
# Out:
#   Div  Season        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0  E1      20  11/09/2020  19:45      Watford  Middlesbrough     1     0   H
# 1  E1      20  12/09/2020  12:30   Birmingham      Brentford     1     0   H
# 2  E1      20  12/09/2020  12:30      Wycombe      Rotherham     0     1   A
# 3  E1      20  12/09/2020  15:00     Barnsley          Luton     0     1   A
# 4  E1      20  12/09/2020  15:00  Bournemouth      Blackburn     3     2   H
#
#    HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...      1.65 -0.50     2.05      1.85   2.04   1.85     2.09
# 1     1  ...      1.67  0.50     1.97      1.93   1.96   1.93     1.97
# 2     0  ...      1.86  0.25     1.99      1.91   1.95   1.93     2.04
# 3     0  ...      1.83 -0.50     1.77      2.02   1.81   2.10     1.87
# 4     1  ...      1.89 -0.50     2.06      1.84   2.07   1.85     2.11
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.88     2.02     1.82
# ...

# %%
dict_countries = {"Spanish La Liga":"SP1","Spanish Segunda Division":"SP2",
                  "German Bundes Liga":"D1","English Premier League":"E0",
                  "English League 1":"E2"}

# %%
dict_countries["Spanish La Liga"]
# Out:
# 'SP1'

# %%
for league in dict_countries:
  print(dict_countries[league])
# Out:
# SP1
# SP2
# D1
# E0
# E2

# %%
dict_history={}

#leagues = ["E1","E2","E3"]
for league in dict_countries:
  frames = []
  for season in range(20,26):
    df = pd.read_csv(root + str(season)+str(season+1) + "/" +   (dict_countries[league]) + ".csv",encoding = "unicode_escape")
    df.insert(1,"Season",season)
    frames.append(df)
    df_concat = pd.concat(frames)
    dict_history[league] = frames

# %%
dict_history["Spanish La Liga"]
# Out:
# [     Div  Season        Date   Time     HomeTeam    AwayTeam  FTHG  FTAG FTR  \
#  0    SP1      20  12/09/2020  15:00        Eibar       Celta     0     0   D
#  1    SP1      20  12/09/2020  17:30      Granada  Ath Bilbao     2     0   H
#  2    SP1      20  12/09/2020  20:00        Cadiz     Osasuna     0     2   A
#  3    SP1      20  13/09/2020  13:00       Alaves       Betis     0     1   A
#  4    SP1      20  13/09/2020  15:00   Valladolid    Sociedad     1     1   D
#  ..   ...     ...         ...    ...          ...         ...   ...   ...  ..
#  375  SP1      20  22/05/2021  17:00      Osasuna    Sociedad     0     1   A
#  376  SP1      20  22/05/2021  17:00  Real Madrid  Villarreal     2     1   H
#  377  SP1      20  22/05/2021  17:00   Valladolid  Ath Madrid     1     2   A
#  378  SP1      20  23/05/2021  17:30      Granada      Getafe     0     0   D
#  379  SP1      20  23/05/2021  20:00      Sevilla      Alaves     1     0   H
#
# ...
